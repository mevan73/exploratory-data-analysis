# %% [markdown]
# # MEAN VS MEDIAN

# %% [raw]
# # Lets create some fake income data, centered around 27,000 with normal distrubution and standard deviation of 15000 with 10000
# #data points. The compute the mean(average)- it should be close to 27,000

# %%
import numpy as np
incomes = np.random.normal(27000,15000,10000)
#plot mean.....................
m = np.mean(incomes)
print(m)
# Out:
# 26983.016794733925

# %%
# %matplotlib inline
from matplotlib import pyplot as ply
#import matplotlib.pyplot as plt
plt.hist(incomes,10)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
incomes = np.random.normal(100.0,50.0,10000)
plt.hist(incomes,50)
plt.show()

# %%
income.std()
# Out:
# 15024.30679143989

# %%
income.var()
# Out:
# 225729794.56330684

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
#import matplotlib.pyplot as plt
plt.hist(incomes,50)
plt.show()

# %%
median=np.median(incomes)
median
# Out:
# 26942.76560060441

# %%
incomes=np.append(incomes,[1000000000])

# %%
np.median(incomes)
# Out:
# 26946.873565089692

# %%
np.mean(incomes)
# Out:
# 126906.22701635967

# %%
#MODE
import numpy as np
ages=np.random.randint(16, high=90, size=500)
ages
# Out:
# array([85, 37, 89, 40, 84, 35, 73, 25, 66, 70, 51, 34, 74, 47, 70, 77, 41,
#        54, 26, 16, 64, 67, 31, 88, 44, 37, 35, 31, 83, 80, 25, 79, 74, 76,
#        41, 85, 83, 23, 86, 37, 87, 65, 16, 66, 16, 28, 38, 28, 30, 43, 79,
#        53, 52, 67, 57, 29, 32, 85, 64, 29, 65, 86, 30, 17, 24, 57, 35, 47,
#        51, 36, 18, 85, 44, 71, 45, 89, 72, 58, 49, 56, 51, 19, 88, 63, 45,
#        17, 54, 43, 80, 46, 55, 73, 38, 35, 25, 22, 55, 40, 64, 76, 40, 69,
#        61, 44, 31, 50, 20, 29, 77, 39, 32, 82, 76, 36, 35, 56, 25, 53, 76,
#        28, 26, 87, 18, 73, 32, 16, 18, 86, 37, 89, 38, 31, 39, 45, 42, 26,
#        88, 33, 30, 59, 48, 44, 72, 70, 57, 44, 40, 79, 65, 42, 89, 21, 18,
#        54, 22, 84, 20, 22, 52, 63, 56, 83, 63, 19, 73, 40, 69, 68, 86, 73,
#        86, 50, 56, 85, 36, 72, 30, 31, 46, 52, 38, 74, 35, 80, 63, 16, 42,
#        86, 65, 42, 75, 84, 65, 27, 79, 81, 38, 24, 39, 18, 38, 57, 48, 26,
# ...

# %%
from scipy import stats
stats.mode(ages)
# Out:
# C:\Users\miche\AppData\Local\Temp\ipykernel_6012\2994774060.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(ages)
# ModeResult(mode=array([45]), count=array([13]))
