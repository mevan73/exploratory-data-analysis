# %%
import numpy as np
import pandas as pd
df1 = pd.DataFrame({
                   'EmployeeID': [1001,1002,1003,1004,1005,1006],
                   'EmployeeName': ['Bob', 'Jake', 'Lisa', 'Sue','Ancy','Jick'],
                   'Dept': ['Accounting', 'Engineering','Engineering','HR','NWT',"NWT"],
                   'Salary': ['AED78000', 'AED998000', 'AED998000', 230000,67000,'AED78000'],
                   'Address': ['Oulu','Kyme','Helsinki','Paris','KYME','NewYork'],
                   'Email': ['b@b.com','j@j.com','l@l.com','s@s.com','a@k.com','j@j.com'],
                   'Project': ['ACM','CRMWEB','AUTOMATION','SAPHRMS','OFA','OFAC']})
df1
# Out:
#    EmployeeID EmployeeName         Dept     Salary   Address    Email  \
# 0        1001          Bob   Accounting   AED78000      Oulu  b@b.com
# 1        1002         Jake  Engineering  AED998000      Kyme  j@j.com
# 2        1003         Lisa  Engineering  AED998000  Helsinki  l@l.com
# 3        1004          Sue           HR     230000     Paris  s@s.com
# 4        1005         Ancy          NWT      67000      KYME  a@k.com
# 5        1006         Jick          NWT   AED78000   NewYork  j@j.com
#
#       Project
# 0         ACM
# 1      CRMWEB
# 2  AUTOMATION
# 3     SAPHRMS
# 4         OFA
# 5        OFAC

# %%
#"C:\Users\Exam\Desktop\python\datastructures-cpp-master\datastructures-cpp-master"
df1.to_csv(r'C:\Users\User\pyproj\employeedbnew.csv')

# %%
df2=pd.read_csv(r'C:\Users\User\pyproj\employeedbnew.csv')
df2
# Out:
#    Unnamed: 0  EmployeeID EmployeeName         Dept     Salary   Address  \
# 0           0        1001          Bob   Accounting   AED78000      Oulu
# 1           1        1002         Jake  Engineering  AED998000      Kyme
# 2           2        1003         Lisa  Engineering  AED998000  Helsinki
# 3           3        1004          Sue           HR     230000     Paris
# 4           4        1005         Ancy          NWT      67000      KYME
# 5           5        1006         Jick          NWT   AED78000   NewYork
#
#      Email     Project
# 0  b@b.com         ACM
# 1  j@j.com      CRMWEB
# 2  l@l.com  AUTOMATION
# 3  s@s.com     SAPHRMS
# 4  a@k.com         OFA
# 5  j@j.com        OFAC

# %%
df2['Salary_nw']=df2['Salary'].replace(r'[^0-9]+','',regex=True)
#print(df)
df2
# Out:
#    Unnamed: 0  EmployeeID EmployeeName         Dept     Salary   Address  \
# 0           0        1001          Bob   Accounting   AED78000      Oulu
# 1           1        1002         Jake  Engineering  AED998000      Kyme
# 2           2        1003         Lisa  Engineering  AED998000  Helsinki
# 3           3        1004          Sue           HR     230000     Paris
# 4           4        1005         Ancy          NWT      67000      KYME
# 5           5        1006         Jick          NWT   AED78000   NewYork
#
#      Email     Project Salary_nw
# 0  b@b.com         ACM     78000
# 1  j@j.com      CRMWEB    998000
# 2  l@l.com  AUTOMATION    998000
# 3  s@s.com     SAPHRMS    230000
# 4  a@k.com         OFA     67000
# 5  j@j.com        OFAC     78000

# %%
df2 = df2.style.format(precision=1, subset=list(df2.columns)).set_properties(**{'background-color':'cyan'}, subset=['Price'])
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:383, in Styler._repr_html_(self)
#     378 """
#     379 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     380 default if an object is returned at the end of a cell.
#     381 """
#     382 if get_option("styler.render.repr") == "html":
# --> 383     return self.to_html()
#     384 return None
#
# ...
